# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavi-code-121/Python-files/blob/main/Vaish_python_class_notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 16-07-2026
#
# **Introduction to python**

# %%
#print "hello world" in python?
# use inbuilt"print()"
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# **Numerical data types**

# %%
# 1.There are 3 numerical data types
# Integer --> int --> A whole numbers either +ve or -ve without decimal point
print(10)
# find the data type  for 10 --> type()
print(type(10))
# Out:
# 10
# <class 'int'>

# %%
# 2.float --> float --> A number either +ve or -ve with deciam point
print(2.5)
print(type(2.5))
# Out:
# 2.5
# <class 'float'>

# %%
print(type(0))
print(type(0.0))
print(type(-5.))
print(type(2))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'int'>

# %%
#3.complex number --> complex --> A real number with its imaginary part
#the imaginary part is denoted with "j" is know as iota
print(2+5j)
print(type(2+5j))
# Out:
# (2+5j)
# <class 'complex'>

# %% [markdown]
# **Arthematic operators**

# %%
# There are 7 arthematic operators
# 1.addition --> +
print(10+5)
print(type(10+5))
# Out:
# 15
# <class 'int'>

# %%
# 2.subtraction --> -
print(10-5)
print(type(10-5))
# Out:
# 5
# <class 'int'>

# %%
# 3. multiplication --> *
print(10*5)
print(type(10*5))
# Out:
# 50
# <class 'int'>

# %%
# 4. Division --> /
print(10/5)
print(type(10/5))
# what is default data type for division ? --> float
# why it is a float -> to get the proper co-efficient the default data type is a float
# Out:
# 2.0
# <class 'float'>

# %%
# 5. modulus --> % --> remainder of the division
# modulus is used to even and odd also used to check prime number detection
print(123%2)
print((24%2))
print(type(24%2))
# Out:
# 1
# 0
# <class 'int'>

# %%
# 6. exponentail --> ** -->  to the poweroff
print(2**3)
print(type(2**3))
# Out:
# 8
# <class 'int'>

# %%
#7. floor division --> // --> it ingnores the values after the decimal point the coefficient
print(10/3)
print(10//3)
# Out:
# 3.3333333333333335
# 3

# %%
# squre root --> 25 --> 5
# squre root 136
print(136**0.5)
# Out:
# 11.661903789690601

# %% [markdown]
# **17-07-2026**

# %%
#round() :- it is applicable to the decimal numbers
#it is used to print floor value and ceil value
print(round(99))
# Out:
# 99

# %%
print(round(2.65))
#if the decimal number is more then 0.5 it print ceil value(next upcoming number)
#if the decimal number is less then o.5 it prints floor value(base value)
# Out:
# 3

# %%
print(round(99.49999999999))
# Out:
# 99

# %%
print(round(65.52))
# Out:
# 66

# %%
#7634.8765432
#roundoff the above number up to 2n-digits
#round(number,ndigits)
print(round(7634.8765432,2))
# Out:
# 7634.88

# %%
print(round(123.4564,2))
# Out:
# 123.46

# %%
print(round(42.467,1))
# Out:
# 42.5

# %%
print(round(12.2344,3))
# Out:
# 12.234

# %% [markdown]
# **Variable**

# %%
# variable are containers where we can store our valuable information and reuse it
# Q) how can we create the variable and how can we access the values from variable ?
""" Father age is 40 and son is half of father age
find the son age
let say father age is x"""
# Out:
# ' Father age is 40 and son is half of father age\nfind the son age\nlet say father age is x'

# %%
x = 40
sonage = x/2
print(sonage)
# Out:
# 20.0

# %% [markdown]
# **Types of errors**

# %%
# There are 2 types of errors i python
# 1. syntax error :- Breaking the inbuilt rules of a programming languages can rise syntax error

# %%
"""hello good afternoon
welcome to medha!'''
# Out:
#   File "/tmp/ipykernel_1687/464904082.py", line 1
#     """hello good afternoon
#     ^
# SyntaxError: incomplete input

# %%
print(2* *3)
# Out:
#   File "/tmp/ipykernel_1687/1359160973.py", line 1
#     print(2* *3)
#              ^
# SyntaxError: invalid syntax

# %%
#2.Logical errors:- except syntax error all other errors comes under logical errors
#ex:- indentation errors, Type error, Name error, recursive error, attribute errors...etc

# %% [markdown]
# ** Rule to create variable**

# %%
#1.strat creating the variable by using the alphabets
sonage = 20
print(sonage)
# Out:
# 20

# %%
#2. dont start creating the variable by using the numbers
2 ="hello"
print(2)
# Out:
#   File "/tmp/ipykernel_1687/3431786231.py", line 2
#     2 ="hello"
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
#3. if we follow rule 182 start creating the variable with alphabets in between use the numbers
son2age = 20
print(son2age)
# Out:
# 20

# %%
#4. dont use the special characters in the variable name --> !,@,#,$,%,^,&,*,-,<space>
son@age = 20
print(sonage)
# Out:
#   File "/tmp/ipykernel_1687/3092948821.py", line 2
#     son@age = 20
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
# 5. start creating the variable by using underscore(_)
_ = 10
print(_)
# Out:
# 10

# %%
son_age = 20
print(son_age)
# Out:
# 20

# %%
# 6. don't use the inbuilt keywords as a variable names
for = 10
pint(for)
# Out:
#   File "/tmp/ipykernel_1687/1054298181.py", line 2
#     for = 10
#         ^
# SyntaxError: invalid syntax

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#7.dont use the uppercase letter as a variable name -->pep8
SON_AGE
son_age
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1687/2161856400.py in <cell line: 0>()
#       1 #7.dont use the uppercase letter as a variable name -->pep8
# ----> 2 SON_AGE
#       3 son_age
#
# NameError: name 'SON_AGE' is not defined

# %% [markdown]
# python is a object oriented programming language

# %%
#each line in python is a object where it has its own identity , attributes and methods
#based this the object belongs to class
a = "hello world!"
#identity --> a
#attributes --> " ",12
#methods --> upper(),lower(),replace()
print(a)
print(type(a))
# Out:
# hello world!
# <class 'str'>

# %%
b = 10
print(type(b))
# Out:
# <class 'int'>

# %%
c = [1,2,3,4,5,6]
print(type(c))
# Out:
# <class 'list'>

# %% [markdown]
# python is a interpreted programming language --> execute code line by line

# %%
a = 10
b = 5
a = 20
b = 6
print(a+b)
# Out:
# 26

# %% [markdown]
# python is a dynamically typed programming language

# %%
#we won;t define the data type for variables
# int a = 10
a = 10
print(type(a))
# Out:
# <class 'int'>

# %% [markdown]
# python is a case sensitive programming language

# %%
c = "hello"
print(C)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1687/2205811908.py in <cell line: 0>()
#       1 c = "hello"
# ----> 2 print(C)
#
# NameError: name 'C' is not defined

# %% [markdown]
# **20-07-2026**

# %%
#what is input()
#input() function takes any kind of information from the user and store it as a string
# how can we create input()
# assign it to a variable
a = input("enter your email")
print(a)
# Out:
# enter your emailkallurvaishnavi48@gmail.com
# kallurvaishnavi48@gmail.com

# %%
# take 2 input and apply 4 basic arthametic operations
num1 = input("enter your num ")
num2 = input("enter your num2")
print(num1+num2)
# Out:
# enter your num 23
# enter your num245
# 2345

# %%
num1 = "20"
num2 = "26"
print(num1+num2)
# adding of 2 string is know as string concatenation
# Out:
# 2026

# %%
# how can we deal with numerical data when we use input function ?
# we need to define data type to input function --> Type casting
a = int(input("enter the number"))
b = int(input("enter the number2 "))
print(a+b)
#int(),float(),Complex()
# Out:
# enter the number24
# enter the number2 34
# 58

# %%
c = float(input("enter decimal number"))
d = float(input("enter decimal number 2"))
print(round(c+d,2))
# Out:
# enter decimal number30.45
# enter decimal number 245.8
# 76.25

# %%
# what is the default data type for input()
# it is a string
# why it is  a string ?
# Because string is the collection multiple characters
# q) when we can use input() ?
# when there more user inputs

# %% [markdown]
# **strings**

# %%
# what is a string?
# string is a collection of muitiple characters where it is declared in "" or ''
# there are 2 types of string
# single line string --> "" or ''
# multiple string --> """ """ or ''' '''

# %%
a = "Hello world!"
# check sum of character in above or find the

print(len(a))
print(type(a))
# Out:
# 12
# <class 'str'>

# %%
 a = """hello goodafternoon!
 welcome to python session .
 Today we are having session about strings"""
 print(a)
# Out:
# hello goodafternoon!
# welcome to python session .
# Today we are having session about strings

# %%
# string is a collection of mutiple character declared in quotes where each character can be accisble
# Q)how can we access the characters from

# %%
a = "Hello world!"
#Sytax :- [start]
#print "w" from above string
print(a[6])
# access "d"
print(a[10])
# Out:
# w
# d

# %%
a = "Hello world!"
# print "world" from above string
# syntax :- [start:end]
print(a[6:11])
# Note :- slicing can stop before one end index position so if we want to print particular end character
# end is always n+1
# Out:
# world

# %%
# print even index characters from the string?
# syntax:[start:end:step]
print(a[0:12:2])
# Out:
# Hlowrd

# %%
# print odd index characters from the string ?
# syntax :- [start:end:step]
print(a[1:12:2])
# Out:
# el ol!

# %% [markdown]
# **21-07-2026**

# %%
#Q)can we convert a string of float to int --> no
a = "25.6"
print(int(a))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1687/2415233834.py in <cell line: 0>()
#       1 #Q)can we convert a string of float to int --> no
#       2 a = "25.6"
# ----> 3 print(int(a))
#
# ValueError: invalid literal for int() with base 10: '25.6'

# %%
#print last character from the given strings
a = "hello world!"
#!
b = "medha"
print(a[len(a)-1])
print(b[len(b)-1])
# Out:
# !
# a

# %% [markdown]
# *Negative indexing ** --> access the range of characters in reverse direction

# %%
a = "hello world!"
#print last character from the string
#[start:end:step]
print(a[-1])
b = "medha"
print(b[-1])
# Out:
# !
# a

# %%
#print "world!" in reverse direction --> "!dlow"
print(a[-1:-7:-1])
# note:- the default slicing direction is from left to right side
#when we reverse a string we need to define step as -1
# Out:
# !dlrow

# %%
print(a[-6:-1])
# Out:
# world

# %%
c = "python"
print(c[-2:-5:-2])
# Out:
# ot

# %%
d = "machine"
print(d[-3:-7:-1])
# Out:
# ihca

# %% [markdown]
# **Default indexing**

# %%
#by default the start is 0 and end is lenght of string and step is 1
a = "Hello world!"
print(a[:])
print(a[0:len(a)])
print(a[::])
print(a[0:len(a):1])
#print the even index position characters
print(a[0:12:2])
print(a[::2])
#odd index characters
print(a[1::2])
print(a[1:12:2])
# Out:
# Hello world!
# Hello world!
# Hello world!
# Hello world!
# Hlowrd
# Hlowrd
# el ol!
# el ol!

# %%
#reverse the entire string
print(a[::-1])
# Out:
# !dlrow olleH

# %%
#check a string is palindrome or not?
# if we reverse a string it give same meaning
a = input("enter your string:")
print(a[::-1])
# Out:
# enter your string:programming
# gnimmargorp

# %% [markdown]
# **string methods**

# %%
#python is object oriented programming language --> OOP's
#The methods those are applicable on string is known as string methods.
a = "hello world!"
#identity  --> a
#properties --> " ", 12
#methods of interaction --> dir() --> return methods applicable on object
print(dir(a))
"""
'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith',
 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum',
  'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier',
   'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle',
    'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans',
     'partition', 'removeprefix', 'removesuffix', 'replace',
      'rfind', 'rindex', 'rjust', 'rpartition',
 'rsplit', 'rstrip', 'split', 'splitlines',
  'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill' """
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
# ...

# %% [markdown]
# **important methods used in project**

# %%
a = "hello world!"
#1.capitalize():- converts first letter to upper case
print(a.capitalize())
# Out:
# Hello world!

# %%
#2.upper() :- convert the entire string to upper case
print(a.upper())
#3.lower():- converts the entire string into lowercase
print(a.lower())
# Out:
# HELLO WORLD!
# hello world!

# %%
#4.replace(old,new)
#replace the world with universe and print hello universe
print(a.replace("world","universe"))
# Out:
# hello universe!

# %%
#5.title():- it converts every first letter of word in upper case
a = "hello world!"
print(a.title())
# Out:
# Hello World!

# %%
#6.strip():- remove unwanted spaces from leading and triling ends
a = "   hello world!   "
print(a)
print(a.strip())
# Out:
#    hello world!
# hello world!

# %%
#7.zfill(num):it takes argument and matches with legth of string by filling zeros infront of string
a = "hello world!"
print(a.zfill(15))
# Out:
# 000hello world!

# %%
#8.swapcase():-
a = "Hello World!"
print(a.swapcase())
# Out:
# hELLO wORLD!

# %%
#9.find()
print(a.find("g"))
# Out:
# -1

# %%
#10:index()
print(a.index("g"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1687/1076805047.py in <cell line: 0>()
#       1 #10:index()
# ----> 2 print(a.index("g"))
#
# ValueError: substring not found

# %% [markdown]
# **22-07-2026**

# %% [markdown]
# **string formatting methods** --> it takes a arugument and place it over the place holders{}.

# %%
age = 10
txt = "my age is _ years old"
print(txt)
# Out:
# my age is _ years old

# %%
# There are three types of string format methods
#1. use the .format() in the print statement
age = 10
txt ="my age is {} years old"
print(txt.format(age))
# Out:
# my age is 10 years old

# %%
# 2. use the .format() method at end of string
age = 10
txt = "my age is {} years old".format(age)
print(txt)
# Out:
# my age is 10 years old

# %%
#3.f"{string} format" method write 'f' infront of the string
age =10
txt = f"my age is {age} year old"
print(txt)
# Out:
# my age is 10 year old

# %%
item_name = input("enter the name")
quantity = int(input("enter quantity"))
price_each = int(input("enter your price"))
notification =f"""your order for item {item_name} is confirmed
Total quantity = {quantity}
TOtal price = {price_each*quantity}/- """
print(notification)
# Out:
# enter the namevivo
# enter quantity24
# enter your price12000
# your order for item vivo is confirmed
# Total quantity = 24
# TOtal price = 288000/-

# %% [markdown]
# **Escape characters **represented with backward slash(\)
#
# --> escape characters are used to print illegal characters --> use() infront of illegal characters

# %%
a = "Dywane \"The Rock\" Jhonson"
print(a)
# Out:
# Dywane "The Rock" Jhonson

# %% [markdown]
# **Summary**
#
# 1. Numerical data types --> int,float,complex
# 2. arthematic operators --> 7types --> +,-,*,/,%,**,//
# 3. round(number,ndigits)
# 4. Variable --> container where we store data and reuse it
# 5. types of error --> 2 types of errors
# 6. rules to create variables
#
#         1. start creating the variable by using alphabets
#         2. dont start with numbers
#         3. dont use special characters
#         4. start the alphbets with letter use the numbers inb/w variable
#         5. start creating varible by using the underscore(_)
#         6. dont use the inbuilt keywords
#         7. don't use upper case letters
# 7. Input():- it take any kind of information and store it inthe form strings
# 8. string concatenation :- adding 2 strings
# 9. Type casting :- convert a string object into particular data type
# 10. string type --> 2types --> is collection of multiple characters declared inside the quotes
# 11. indexing --> posiitonal of each character in the string
# 12. slicing --> the process of accessing a range of characters
# 13. substring --> range of characters from main string
# 14. types of indexing --> 3types
# 15. string methods -->  dir()
# 16. string format methods  --> f"string{format} method"
# 17. escape characters --> used to print illegal characters --> \

# %% [markdown]
# **Assignment Operator**(=)

# %%
x = 5
print(x)
# Out:
# 5

# %%
a =10
a += 5
print(a)
# Out:
# 15

# %%
b = 2
b *=3
print(b)
# Out:
# 6

# %%
c = 36
c %= 6
print(c)
# Out:
# 0

# %%
a  = "python"
#reverse the string
print(a[::-1])
# Out:
# nohtyp

# %%
b = "data-analysis"
print(b[5:10][1:3]) # sub-slicing
# Out:
# na

# %%
#how can we check a condition is true or false?
#comparision operatrors / relational operators --> 6types
"""1.  equals to --> ==
   2. not equals to --> !=
   3. greater then --> >
   4. less then --> <
   5. less then or equals to -->  <=
   6. greater then or equals to --> >= """
# Out:
# '1.  equals to --> ==\n   2. not equals to --> !=\n   3. greater then --> >\n   4. less then --> <\n   5. less then or equals to -->  <=\n   6. greater then or equals to --> >= '

# %%
print(10==10)
# Out:
# True

# %%
print(2<=5)
# Out:
# True

# %% [markdown]
# **29-07-2026**

# %% [markdown]
# **Conditional Statements**

# %%
#conditional statements are used to check a condition is satisfied or not
#to build the decision making codes we use conditional satements
#Q)How can we check a condition is true or false inside the conditional statements?
#By using "comparision operators" or relational operators
#Q)how many comparision operators do we have?
# there 6 types
"""1.equals too --> ==
   2.Not equals to --> !=
   3.greater then --> '>'
   4.less then --->   '<'
   5.less then or equals to --> '<='
   6.greater then or equals to -->  '>='  """
#Q)How many conditional statements do we have in python?
#There are 3 conditional statements
#1.if :- is used to check a condition is true
#2.elif:- is used when there is more then 2 conditions to check
#3.else:- used to check the false condition
# Out:
# "1.equals too --> ==\n   2.Not equals to --> !=\n   3.greater then --> '>'\n   4.less then --->   '<'\n   5.less then or equals to --> '<='\n   6.greater then or equals to -->  '>='  "

# %%
#write a pragram to check a student is pass or fail
# if marks is greater then or equal to 45--> print "Congratualtion"
# if the student get less then 45 then print "better luck next time"

marks = int(input("Enter a number:"))
if marks >= 45:
  print("Congratulations")
else:
  print("better luck next time")
# Out:
# Enter a number:56
# Congratulations

# %%
# Write program to check a number is odd or even

nums = int(input("Enter number:"))

if nums%2 == 0:
  print("even")
else:
  print("odd")
# Out:
# Enter number:23
# odd

# %%
# write program to check a number is positive or negative if the number is zero print it as neutral ?
num = int(input("Enter a number:"))

if num > 0:
  print("+ve")
elif num == 0:
  print("neutral")
else:
  print("-ve")
# Out:
# Enter a number:45
# +ve

# %% [markdown]
# **Logical operators**
# 1. And :- is used to execute a block of code when all the condition are true
# 2. or :- is used to execute a block of code when any one condition is satisfied
# 3. no :- it reverse your actual output
#
# To check all the conditions at a time we use logical operators

# %%
a = 25
b = 15
c = 45
d = 50
# check that a is greater then b and c is greater then a and d is greater then c
# if all the conditions are then print "all conditions satisfied"
# Otherwise print "not "

if a>b and c>b and d>a:
  print("All the conditions Satisfied")
else:
  print("not satisfied")
# note : if there is more then 2 conditions to check use elif
# if we want to check multiple conditions at a time we use logical operators
# Out:
# All the conditions Satisfied

# %%
print(1==1)
# Out:
# True

# %%
print(not(1==1))
# Out:
# False

# %%
# write program to check admission elgibility in a college
# The collegen consider only three subject marks to get the admission --> maths,physics,and chemistry
# to get the admission maths marks has to be greater then or equals to 75
# Physics marks greater then or equals to 55
# chemistry marks greater then or equals to 55
# if the above all conditions are satisfied print "eligible for admission"
# Other wise print "not eligible"

# %%
a = 25
b = 15
c = 45
d = 50

# check a is greater then d and c is greater then b and a is greater then c
# if any one condition is true print --> condition satisfied
# else print "all the conditions are false"
if a>d or c>b or a>c:
  print("condition satisfied")
else:
  print("not satisfied")
# Out:
# condition satisfied

# %%
# write a program to check a customer is elibigle discount or not
# if the customer purchaser more then 5000 and if the customer is permimum member
# in above if any one condition satisfied print eligible for discount

premium = bool(input("enter True or False"))
purchase = 4500

if purchase>=5000 or premium ==True:
  print("eligible for discount")
else:
  print("not eligible")
# Out:
# enter True or FalseTrue
# eligible for discount

# %%
#what is the poutpus of following code
print(True and False or True)
# Out:
# True

# %%
print(False and True or False)
# Out:
# False

# %%
print(not False and False)
# Out:
# False

# %% [markdown]
# **30-07-2026**

# %% [markdown]
# **Nested COndition**

# %%
# what is nested condition?
# writing a condition inside another condition is known as nested conditions
# what is the purpose of Nested conditions?
# A current block of code can be executed if the previous conditions is True
a = 35
# check the at is greater then 10,20,30,40
# if a is greater then 10 print a is greater then 10
# if a is greater then 20 print a is greater then 20
# if a is greater then 30 print a is greater then 30
# if a is greater then 40 print a is greater then 40

# %%
 a =25
 if a>10:
  print("a is greater then 10")
  if a>20:
    print("a is greater then 20")
    if a>30:
      print("a is greater then 30")
      if a>40:
        print("a is greater then 40")
      else:
        print("a is less then 40")

    else:
      print("a is less then 30")
  else:
    print("a is less then 20")
else:
  print("a is less then 10")
# Out:
# a is greater then 10
# a is greater then 20
# a is less then 30

# %%
# write a programm to check a number is divisible with 3 and 5
# if the number divisible with 3 and 5 print yes divisible with 3 and 5
# Other if the numbern divisible either with 5 print number divisible with 5
# else print number not divisible
#modulus --> % --> num%3==0 and num%5==0  print
#elif num%3==0 :
#elif num%5==0 :
#else:
num = int(input("enter number "))
if num%3==0 and num%5==0:
  print("number divisibl;e with both 3 and 5")
elif num%3==0:
  print("number is divisible with 3")
elif num%5==0:
  print("number is divisible with 5")
else:
  print("number is not divisible")

# %%
nums = int(input("Enter a number:"))

if nums%3 == 0 and nums%5 == 0:
  print("number divisible with both 3 and 5")
elif nums%3 == 0:
  print("number is divisible with 3")
elif nums%5 ==0:
  print("number is divisible with 5")
else:
  print("number is not divisible")
# Out:
# Enter a number:0
# number divisible with both 3 and 5

# %%
# write a program to print grades of a student based on recieved marks
# if the marks between 50 to 60 print "Congratulation you have recived "d" grade
# if the marks between 61 to 70 print "Congratulation you have recived "c" grade
# if the marks between 71 to 80 print "Congratulation you have recived "b" grade
# if the marks between 81 to 90 print "Congratulation you have recived "a" grade
# if the marks between 91 to 100 print "Congratulation you have recived "a+" grade
# if the marks more then 100 print "invalid" marks
# if the less then 50  print better luck next time
# Use the nested condition along with elif statments
marks = int(input("enter marks"))
if marks <= 100:
  if marks>=50 and marks<=60:
    print("congratulation you have recived D grade")
  elif marks>=61 and marks<=70:
    print("congratulation you have recived C grade")
  elif marks>=71 and marks<=80:
    print("congratulation you have recived B grade")

  else:
    print("better luck next time")
else:
  print("invaild marks")
# Out:
# enter marks80
# congratulation you have recived B grade

# %% [markdown]
# **Terinary Operator** :- offers single line of code to solve a problem
#
# Terinary operator is applicable when there is only 2 condition

# %%
# syntax:- True <space> if condition <space> else <space> False
# write a simple program to check eligibility for vote
# age >= 18 yes eligible else print NOt eligible
age = int(input("Enter age:"))
if age>= 18:
   print("eligible")
else:
  print("not eligible")
# Out:
# Enter age:34
# eligible

# %%
age = int(input("Enter a age"))

print("eligible"if age>=18 else "Not eligible")
# Out:
# Enter a age12
# Not eligible
